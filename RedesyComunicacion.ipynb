# %%
import networkx as nx
import matplotlib.pyplot as plt

red = nx.DiGraph()

# Declaracion de nodos en un array
nodos = [
    "Nodo A", "Nodo B", "Nodo C", "Nodo D",
    "Nodo E", "Nodo F", "Nodo G", "Nodo H"
]

# Agrego los nodos declarados a la red para empezar a destinar sus comunicaciones
for nodo in nodos:
    red_nueva.add_node(nodo)

# Creo conexiones donde cada nodo apunta a los dos siguientes en un ciclo
conexion = [
    ("Nodo A", "Nodo B"), ("Nodo A", "Nodo C"),
    ("Nodo B", "Nodo C"), ("Nodo B", "Nodo D"),
    ("Nodo C", "Nodo D"), ("Nodo C", "Nodo E"),
    ("Nodo D", "Nodo E"), ("Nodo D", "Nodo F"),
    ("Nodo E", "Nodo F"), ("Nodo E", "Nodo G"),
    ("Nodo F", "Nodo G"), ("Nodo F", "Nodo H"),
    ("Nodo G", "Nodo H"), ("Nodo G", "Nodo A"),
    ("Nodo H", "Nodo A"), ("Nodo H", "Nodo B")
]

for origen, destino in conexion:
    red.add_edge(origen, destino)

# Visualizar la nueva red
pos = nx.circular_layout(red) # Posiciones circulares para los nodos
nx.draw(red, pos, with_labels=True, node_color='lightblue', edge_color='green', arrows=True)
plt.title("Red Direccionada con 2 Conexiones por Nodo")
plt.show()
